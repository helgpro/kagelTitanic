# %%
import pickle# для манипуляц со словариком пикл
import numpy as np
import pandas as pd
#from tqdm import tqdm_notebook
from scipy.sparse import csr_matrix, hstack # добавит новый столбец не разряженный к разряженной матрице
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from IPython.display import HTML
style = "<style>svg{width:10% !important;height:10% !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:10% !important;height:10% !important;}</style>

# %%
train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')

# %%
train_df.isnull().sum()
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.loc[train_df.Sex=='male',['Sex','Cabin']]

# %%
train_df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train_df.pivot_table(index='PassengerId',columns='Embarked', values='name',aggfunc='count',fill_value=0)

# аргументы 1 что будет id-ком 2 каие колонки будут участв 3 перемен по которой считаеться в примере был id задания в итоге вывод 
# по юзер id  показал количество заданий посмотреныхб пройденых и т д, там где пустоты забить нолями
# Out:
# Embarked     C  Q  S
# PassengerId
# 1            0  0  1
# 2            1  0  0
# 3            0  0  1
# 4            0  0  1
# 5            0  0  1
# 6            0  1  0
# 7            0  0  1
# 8            0  0  1
# 9            0  0  1
# 10           1  0  0
# 11           0  0  1
# 12           0  0  1
# 13           0  0  1
# 14           0  0  1
# 15           0  0  1
# 16           0  0  1
# 17           0  1  0
# 18           0  0  1
# 19           0  0  1
# 20           1  0  0
# 21           0  0  1
# 22           0  0  1
# 23           0  1  0
# 24           0  0  1
# 25           0  0  1
# 26           0  0  1
# 27           1  0  0
# 28           0  0  1
# 29           0  1  0
# 30           0  0  1
# ...         .. .. ..
# 862          0  0  1
# 863          0  0  1
# 864          0  0  1
# 865          0  0  1
# 866          0  0  1
# 867          1  0  0
# 868          0  0  1
# 869          0  0  1
# 870          0  0  1
# 871          0  0  1
# ...

# %%
train_df = train_df.rename(columns={'Sex':'sex','Name':'name','Age':'age'})

# %%
train_df.query('age > 17')
train_df.query('sex =="male" | age < 30')
train_df.query("sex =='male' & age > 20")
pereme = 30
train_df.query('age < @pereme')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 12            13         0       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 27            28         0       1
# 34            35         0       1
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 49            50         0       3
# 50            51         0       3
# 51            52         0       3
# 53            54         1       2
# 56            57         1       2
# ...

# %%
[i for i in list(train_df)if 'S' in i]# отобрать поля где в названиях есть S
#list(train_df)
# Out:
# ['Survived', 'SibSp']

# %%
train_df.filter(like='S')
train_df.filter(like='e', axis=1)
# Out:
#      PassengerId  Survived                                               name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# 5              6         0                                   Moran, Mr. James
# 6              7         0                            McCarthy, Mr. Timothy J
# 7              8         0                     Palsson, Master. Gosta Leonard
# 8              9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
train_df.groupby('sex').mean()
train_df.groupby('sex', as_index=False).aggregate({'age':'mean','Fare':'median'})\
.rename(columns={'age':'mean_age','Fare':'median_fare'})
# Out:
#       sex   mean_age  median_fare
# 0  female  27.915709         23.0
# 1    male  30.726645         10.5

# %%
train_df.groupby(['sex','Survived'], as_index=False).aggregate({'age':'mean','Fare':'median'})\
.rename(columns={'age':'mean_age','Fare':'median_fare'})
# Out:
#       sex  Survived   mean_age  median_fare
# 0  female         0  25.046875     15.24580
# 1  female         1  28.847716     26.00000
# 2    male         0  31.618056      9.41665
# 3    male         1  27.276022     26.28750

# %%
train_df.sort_values(['sex','Fare'],ascending=False).groupby('sex').head()
# Out:
#      PassengerId  Survived  Pclass                                   name  \
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 438          439         0       1                      Fortune, Mr. Mark
# 118          119         0       1               Baxter, Mr. Quigg Edmond
# 258          259         1       1                       Ward, Miss. Anna
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         sex   age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
Xtr = train_df.drop(['PassengerId','Survived','Name','Cabin','Ticket'], axis = 1)
Y =train_df.Survived

# %%
X = pd.get_dummies(Xtr)
X= X.fillna(0)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=17,criterion='entropy')
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=17, splitter='best')

# %%
#graph = Source(tree.export_graphviz(clf,out_file=None, feature_names=list(X),class_names=['Died', 'Survived'],filled=True))
#display(SVG(graph.pipe(format='svg')))

# %%
train_df,groupby('Pclass')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ca6343577323> in <module>
# ----> 1 train_df,groupby('Pclass')
#
# NameError: name 'groupby' is not defined
